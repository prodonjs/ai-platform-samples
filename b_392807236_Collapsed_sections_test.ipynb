# %% [markdown]
# <a href="https://colab.research.google.com/github/prodonjs/ai-platform-samples/blob/master/b_392807236_Collapsed_sections_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My first section

# %%
print('hello world')

# %% [markdown]
# # Another section

# %% [markdown]
# ## Here's some useful stuff
#
# - First point
# - Second point
# - Again
#
# ### I'm not so sure about that

# %%
import random
for _ in range(100):
    random_string = [str(random.randint(0,9)) for _ in range(36)]
    print(''.join(random_string))
# Out:
# 890214027363212694966014931175933914
# 560970674482458338230212734847614288
# 418755348896136129066649445046190970
# 197313526855939779924020961686737326
# 825541344015861550112404604945848671
# 311473993517730887881941711861282977
# 665819469811897852015357184939989071
# 090523980018595140731133613645650376
# 866265657203687356978276848931670927
# 096052787946620575994136929663309250
# 204779436625399964999881606717359703
# 840696685999505786166269862392273378
# 739593922452936944074067296275949921
# 706210945419221610392161162336559952
# 352832424332272753056465347855277487
# 909574849821676536052334096681116509
# 020141716874273556113975272581689671
# 051201204868381919801442693692452436
# 287322152320142414452085721397765703
# 645198018436583356579591229041729036
# 339613691359034899820099401493106824
# 052067868021185888912892605120947892
# 696228226744566631915764647476944940
# 662781010329012623380867341027507993
# 123350240490138454232587087815503030
# ...
